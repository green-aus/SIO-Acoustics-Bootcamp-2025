# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.signal
from scipy.io import wavfile

# %%
# %matplotlib inline

# %%
HydroA = wavfile.read('PLoc1_amb_001.wav')
HydroB = wavfile.read('PLoc1_amb_002.wav')
HydroC = wavfile.read('PLoc1_amb_003.wav')
HydroD = wavfile.read('PLoc1_amb_004.wav')
HydroE = wavfile.read('PLoc1_amb_005.wav')
SampleRate = 48000

# %%
HydroA[0]
# Out:
# 48000

# %%
Time = np.arange(0,len(HydroA[1])/SampleRate,1/SampleRate)

# %%
a = 0
b = 820435
print(Time[a],Time[b])
plt.figure(figsize=(5,5))
plt.plot(Time[a:b],HydroA[1][a:b]*10e-8, label='A')
plt.plot(Time[a:b],HydroB[1][a:b]*10e-8, label='B')
plt.plot(Time[a:b],HydroC[1][a:b]*10e-8, label='C')
plt.plot(Time[a:b],HydroD[1][a:b]*10e-8, label='D')
plt.plot(Time[a:b],HydroE[1][a:b]*10e-8, label='E')
#plt.xlim(11.2,11.3)
plt.legend()
# Out:
# 0.0 17.09239583333333
